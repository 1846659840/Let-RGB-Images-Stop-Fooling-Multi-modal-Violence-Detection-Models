# %%
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for tensorflow-docs (setup.py) ... done

# %%
import os
import keras
from keras import layers
from keras.applications.densenet import DenseNet121
from tensorflow_docs.vis import embed
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import imageio
import cv2

# %%
MAX_SEQ_LENGTH = 20
NUM_FEATURES = 1024
IMG_SIZE = 128

EPOCHS = 200

# %%
import os
import numpy as np
import cv2
from tensorflow import keras
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import CenterCrop, Input
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split


IMG_SIZE = 224
MAX_SEQ_LENGTH = 120
NUM_FEATURES = 1024


center_crop_layer = keras.layers.CenterCrop(IMG_SIZE, IMG_SIZE)

def crop_center(frame):
    cropped = center_crop_layer(frame[None, ...])
    cropped = keras.backend.squeeze(cropped, axis=0)
    return cropped.numpy()

def load_video(path, max_frames=0, offload_to_cpu=False):
    cap = cv2.VideoCapture(path)
    frames = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = frame[:, :, [2, 1, 0]]  # BGR到RGB
            frame = crop_center(frame)
            frames.append(frame)

            if len(frames) == max_frames:
                break
    finally:
        cap.release()
    return np.array(frames)

def build_feature_extractor():
    feature_extractor = DenseNet121(weights="imagenet", include_top=False, pooling="avg", input_shape=(IMG_SIZE, IMG_SIZE, 3))
    preprocess_input = keras.applications.densenet.preprocess_input
    inputs = Input((IMG_SIZE, IMG_SIZE, 3))
    x = preprocess_input(inputs)
    outputs = feature_extractor(x)
    model = Model(inputs, outputs, name="feature_extractor")
    return model

feature_extractor = build_feature_extractor()

def prepare_videos(root_dir):
    frame_features = []
    labels = []
    for label in ['0', '1']:
        class_dir = os.path.join(root_dir, label)
        for video_file in os.listdir(class_dir):
            video_path = os.path.join(class_dir, video_file)
            frames = load_video(video_path, max_frames=MAX_SEQ_LENGTH)
            frames_feature = np.zeros((MAX_SEQ_LENGTH, NUM_FEATURES))
            for i, frame in enumerate(frames):
                if i < MAX_SEQ_LENGTH:
                    frame = np.expand_dims(frame, axis=0)  # 添加批次维度
                    frames_feature[i] = feature_extractor.predict(frame)
            frame_features.append(frames_feature)
            labels.append(int(label))
    frame_features = np.array(frame_features)
    labels = np.array(labels)
    return frame_features, labels

root_dir = '/content/drive/MyDrive/ViolenceDataPaper2'

frame_features, labels = prepare_videos(root_dir)


X_train, X_test, y_train, y_test = train_test_split(frame_features, labels, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)  # 0.25 * 0.8 = 0.2

print(f"训练集特征维度: {X_train.shape}, 训练集标签维度: {y_train.shape}")
print(f"验证集特征维度: {X_val.shape}, 验证集标签维度: {y_val.shape}")
print(f"测试集特征维度: {X_test.shape}, 测试集标签维度: {y_test.shape}")
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# ...
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 训练集特征维度: (147, 120, 1024), 训练集标签维度: (147,)
# 验证集特征维度: (50, 120, 1024), 验证集标签维度: (50,)
# 测试集特征维度: (50, 120, 1024), 测试集标签维度: (50,)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.optim import Adam

# %%
class PositionalEmbedding(nn.Module):
    def __init__(self, sequence_length, embed_size):
        super(PositionalEmbedding, self).__init__()
        self.position_embeddings = nn.Embedding(num_embeddings=sequence_length, embedding_dim=embed_size)

    def forward(self, x):
        positions = torch.arange(0, x.size(1)).unsqueeze(0).to(x.device)
        x = x + self.position_embeddings(positions)
        return x

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, embed_size, dense_dim, num_heads):
        super(TransformerEncoder, self).__init__()
        self.attention = nn.MultiheadAttention(embed_dim=embed_size, num_heads=num_heads, dropout=0.3)
        self.dense_proj = nn.Sequential(
            nn.Linear(embed_size, dense_dim),
            nn.GELU(),
            nn.Linear(dense_dim, embed_size)
        )
        self.layernorm1 = nn.LayerNorm(embed_size)
        self.layernorm2 = nn.LayerNorm(embed_size)

    def forward(self, src):
        src_attended, _ = self.attention(src, src, src)
        src = self.layernorm1(src + src_attended)
        src_proj = self.dense_proj(src)
        src = self.layernorm2(src + src_proj)
        return src

# %%
class VideoClassifier(nn.Module):
    def __init__(self, sequence_length, num_features, embed_size, dense_dim, num_heads, num_classes):
        super(VideoClassifier, self).__init__()
        self.pos_embedding = PositionalEmbedding(sequence_length, num_features)
        self.transformer_encoder = TransformerEncoder(embed_size, dense_dim, num_heads)
        self.global_pool = nn.AdaptiveAvgPool1d(1)
        self.dropout = nn.Dropout(0.5)
        self.fc = nn.Linear(num_features, num_classes)

    def forward(self, x):
        x = self.pos_embedding(x)
        x = x.permute(1, 0, 2)  # Transformer expects (Seq Len, Batch, Features)
        x = self.transformer_encoder(x)
        x = x.permute(1, 2, 0)  # Pooling expects (Batch, Features, Seq Len)
        x = self.global_pool(x).squeeze(2)
        x = self.dropout(x)
        x = self.fc(x)
        return x

# %%
EPOCHS = 5

# %%
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor.view(-1, 1))
train_loader = DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)

val_dataset = TensorDataset(X_val_tensor, y_val_tensor.view(-1, 1))
val_loader = DataLoader(dataset=val_dataset, batch_size=64, shuffle=False)

test_dataset = TensorDataset(X_test_tensor, y_test_tensor.view(-1, 1))
test_loader = DataLoader(dataset=test_dataset, batch_size=64, shuffle=False)

# %%
def train_model(model, train_loader, val_loader, num_epochs):
    optimizer = Adam(model.parameters(), lr=1e-3)
    criterion = nn.BCEWithLogitsLoss()

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        # 验证逻辑
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for inputs, targets in val_loader:
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                val_loss += loss.item()

        avg_train_loss = train_loss / len(train_loader)
        avg_val_loss = val_loss / len(val_loader)
        print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')

    return model

# %%
model = VideoClassifier(
    sequence_length=MAX_SEQ_LENGTH,
    num_features=NUM_FEATURES,
    embed_size=1024,
    dense_dim=128,
    num_heads=4,
    num_classes=1
)

# %%
EPOCHS = 240  # 或根据您的需求调整

# 开始训练模型
trained_model = train_model(model, train_loader, val_loader, EPOCHS)
# Out:
# Epoch 1/240, Train Loss: 1.3405, Val Loss: 0.5528
# Epoch 2/240, Train Loss: 0.8405, Val Loss: 0.5072
# Epoch 3/240, Train Loss: 0.5303, Val Loss: 0.3757
# Epoch 4/240, Train Loss: 0.4274, Val Loss: 0.7187
# Epoch 5/240, Train Loss: 0.3609, Val Loss: 0.4532
# Epoch 6/240, Train Loss: 0.4068, Val Loss: 0.2813
# Epoch 7/240, Train Loss: 0.1825, Val Loss: 0.1304
# Epoch 8/240, Train Loss: 0.1446, Val Loss: 0.1361
# Epoch 9/240, Train Loss: 0.0851, Val Loss: 0.2061
# Epoch 10/240, Train Loss: 0.1422, Val Loss: 0.2090
# Epoch 11/240, Train Loss: 0.0709, Val Loss: 0.0614
# Epoch 12/240, Train Loss: 0.0503, Val Loss: 0.0513
# Epoch 13/240, Train Loss: 0.0176, Val Loss: 0.0194
# Epoch 14/240, Train Loss: 0.0109, Val Loss: 0.0341
# Epoch 15/240, Train Loss: 0.0061, Val Loss: 0.0311
# Epoch 16/240, Train Loss: 0.0043, Val Loss: 0.0088
# Epoch 17/240, Train Loss: 0.0026, Val Loss: 0.0229
# Epoch 18/240, Train Loss: 0.0018, Val Loss: 0.0329
# Epoch 19/240, Train Loss: 0.0016, Val Loss: 0.0137
# Epoch 20/240, Train Loss: 0.0010, Val Loss: 0.0042
# Epoch 21/240, Train Loss: 0.0007, Val Loss: 0.0041
# Epoch 22/240, Train Loss: 0.0005, Val Loss: 0.0061
# Epoch 23/240, Train Loss: 0.0006, Val Loss: 0.0093
# Epoch 24/240, Train Loss: 0.0003, Val Loss: 0.0102
# Epoch 25/240, Train Loss: 0.0003, Val Loss: 0.0096
# Epoch 26/240, Train Loss: 0.0003, Val Loss: 0.0081
# Epoch 27/240, Train Loss: 0.0002, Val Loss: 0.0064
# Epoch 28/240, Train Loss: 0.0003, Val Loss: 0.0052
# Epoch 29/240, Train Loss: 0.0002, Val Loss: 0.0042
# Epoch 30/240, Train Loss: 0.0002, Val Loss: 0.0034
# Epoch 31/240, Train Loss: 0.0002, Val Loss: 0.0032
# Epoch 32/240, Train Loss: 0.0002, Val Loss: 0.0031
# Epoch 33/240, Train Loss: 0.0002, Val Loss: 0.0029
# Epoch 34/240, Train Loss: 0.0001, Val Loss: 0.0027
# Epoch 35/240, Train Loss: 0.0001, Val Loss: 0.0027
# Epoch 36/240, Train Loss: 0.0001, Val Loss: 0.0027
# Epoch 37/240, Train Loss: 0.0001, Val Loss: 0.0028
# Epoch 38/240, Train Loss: 0.0001, Val Loss: 0.0030
# Epoch 39/240, Train Loss: 0.0001, Val Loss: 0.0032
# Epoch 40/240, Train Loss: 0.0001, Val Loss: 0.0033
# Epoch 41/240, Train Loss: 0.0001, Val Loss: 0.0034
# Epoch 42/240, Train Loss: 0.0001, Val Loss: 0.0033
# Epoch 43/240, Train Loss: 0.0001, Val Loss: 0.0031
# Epoch 44/240, Train Loss: 0.0001, Val Loss: 0.0027
# Epoch 45/240, Train Loss: 0.0001, Val Loss: 0.0025
# Epoch 46/240, Train Loss: 0.0001, Val Loss: 0.0028
# Epoch 47/240, Train Loss: 0.0001, Val Loss: 0.0031
# Epoch 48/240, Train Loss: 0.0001, Val Loss: 0.0034
# Epoch 49/240, Train Loss: 0.0001, Val Loss: 0.0036
# Epoch 50/240, Train Loss: 0.0001, Val Loss: 0.0040
# Epoch 51/240, Train Loss: 0.0001, Val Loss: 0.0042
# Epoch 52/240, Train Loss: 0.0001, Val Loss: 0.0041
# Epoch 53/240, Train Loss: 0.0001, Val Loss: 0.0037
# Epoch 54/240, Train Loss: 0.0001, Val Loss: 0.0032
# Epoch 55/240, Train Loss: 0.0001, Val Loss: 0.0027
# Epoch 56/240, Train Loss: 0.0001, Val Loss: 0.0024
# Epoch 57/240, Train Loss: 0.0001, Val Loss: 0.0021
# Epoch 58/240, Train Loss: 0.0001, Val Loss: 0.0021
# Epoch 59/240, Train Loss: 0.0001, Val Loss: 0.0021
# Epoch 60/240, Train Loss: 0.0001, Val Loss: 0.0023
# Epoch 61/240, Train Loss: 0.0001, Val Loss: 0.0024
# Epoch 62/240, Train Loss: 0.0001, Val Loss: 0.0025
# Epoch 63/240, Train Loss: 0.0001, Val Loss: 0.0025
# Epoch 64/240, Train Loss: 0.0001, Val Loss: 0.0023
# Epoch 65/240, Train Loss: 0.0001, Val Loss: 0.0022
# Epoch 66/240, Train Loss: 0.0001, Val Loss: 0.0021
# Epoch 67/240, Train Loss: 0.0001, Val Loss: 0.0020
# Epoch 68/240, Train Loss: 0.0001, Val Loss: 0.0019
# Epoch 69/240, Train Loss: 0.0001, Val Loss: 0.0019
# Epoch 70/240, Train Loss: 0.0001, Val Loss: 0.0019
# Epoch 71/240, Train Loss: 0.0001, Val Loss: 0.0020
# Epoch 72/240, Train Loss: 0.0001, Val Loss: 0.0020
# Epoch 73/240, Train Loss: 0.0001, Val Loss: 0.0018
# Epoch 74/240, Train Loss: 0.0001, Val Loss: 0.0017
# Epoch 75/240, Train Loss: 0.0001, Val Loss: 0.0017
# Epoch 76/240, Train Loss: 0.0001, Val Loss: 0.0016
# Epoch 77/240, Train Loss: 0.0001, Val Loss: 0.0015
# Epoch 78/240, Train Loss: 0.0001, Val Loss: 0.0014
# Epoch 79/240, Train Loss: 0.0001, Val Loss: 0.0014
# Epoch 80/240, Train Loss: 0.0001, Val Loss: 0.0014
# Epoch 81/240, Train Loss: 0.0001, Val Loss: 0.0015
# Epoch 82/240, Train Loss: 0.0001, Val Loss: 0.0015
# Epoch 83/240, Train Loss: 0.0001, Val Loss: 0.0014
# Epoch 84/240, Train Loss: 0.0001, Val Loss: 0.0014
# Epoch 85/240, Train Loss: 0.0001, Val Loss: 0.0014
# Epoch 86/240, Train Loss: 0.0000, Val Loss: 0.0014
# Epoch 87/240, Train Loss: 0.0001, Val Loss: 0.0013
# Epoch 88/240, Train Loss: 0.0000, Val Loss: 0.0013
# Epoch 89/240, Train Loss: 0.0001, Val Loss: 0.0012
# Epoch 90/240, Train Loss: 0.0001, Val Loss: 0.0012
# Epoch 91/240, Train Loss: 0.0000, Val Loss: 0.0012
# Epoch 92/240, Train Loss: 0.0000, Val Loss: 0.0012
# Epoch 93/240, Train Loss: 0.0001, Val Loss: 0.0012
# Epoch 94/240, Train Loss: 0.0000, Val Loss: 0.0012
# Epoch 95/240, Train Loss: 0.0000, Val Loss: 0.0012
# Epoch 96/240, Train Loss: 0.0000, Val Loss: 0.0013
# Epoch 97/240, Train Loss: 0.0000, Val Loss: 0.0013
# Epoch 98/240, Train Loss: 0.0000, Val Loss: 0.0013
# Epoch 99/240, Train Loss: 0.0001, Val Loss: 0.0013
# Epoch 100/240, Train Loss: 0.0000, Val Loss: 0.0013
# Epoch 101/240, Train Loss: 0.0000, Val Loss: 0.0012
# Epoch 102/240, Train Loss: 0.0000, Val Loss: 0.0012
# Epoch 103/240, Train Loss: 0.0000, Val Loss: 0.0012
# Epoch 104/240, Train Loss: 0.0001, Val Loss: 0.0012
# Epoch 105/240, Train Loss: 0.0001, Val Loss: 0.0012
# Epoch 106/240, Train Loss: 0.0000, Val Loss: 0.0012
# Epoch 107/240, Train Loss: 0.0000, Val Loss: 0.0012
# Epoch 108/240, Train Loss: 0.0000, Val Loss: 0.0012
# Epoch 109/240, Train Loss: 0.0000, Val Loss: 0.0011
# Epoch 110/240, Train Loss: 0.0000, Val Loss: 0.0011
# Epoch 111/240, Train Loss: 0.0000, Val Loss: 0.0010
# Epoch 112/240, Train Loss: 0.0000, Val Loss: 0.0010
# Epoch 113/240, Train Loss: 0.0000, Val Loss: 0.0010
# Epoch 114/240, Train Loss: 0.0000, Val Loss: 0.0009
# Epoch 115/240, Train Loss: 0.0000, Val Loss: 0.0009
# Epoch 116/240, Train Loss: 0.0000, Val Loss: 0.0009
# Epoch 117/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 118/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 119/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 120/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 121/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 122/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 123/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 124/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 125/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 126/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 127/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 128/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 129/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 130/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 131/240, Train Loss: 0.0000, Val Loss: 0.0008
# Epoch 132/240, Train Loss: 0.0000, Val Loss: 0.0007
# Epoch 133/240, Train Loss: 0.0000, Val Loss: 0.0007
# Epoch 134/240, Train Loss: 0.0000, Val Loss: 0.0007
# Epoch 135/240, Train Loss: 0.0000, Val Loss: 0.0007
# Epoch 136/240, Train Loss: 0.0000, Val Loss: 0.0007
# Epoch 137/240, Train Loss: 0.0000, Val Loss: 0.0007
# Epoch 138/240, Train Loss: 0.0000, Val Loss: 0.0007
# Epoch 139/240, Train Loss: 0.0000, Val Loss: 0.0007
# Epoch 140/240, Train Loss: 0.0000, Val Loss: 0.0007
# Epoch 141/240, Train Loss: 0.0000, Val Loss: 0.0007
# Epoch 142/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 143/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 144/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 145/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 146/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 147/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 148/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 149/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 150/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 151/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 152/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 153/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 154/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 155/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 156/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 157/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 158/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 159/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 160/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 161/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 162/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 163/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 164/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 165/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 166/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 167/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 168/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 169/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 170/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 171/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 172/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 173/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 174/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 175/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 176/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 177/240, Train Loss: 0.0000, Val Loss: 0.0006
# Epoch 178/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 179/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 180/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 181/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 182/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 183/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 184/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 185/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 186/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 187/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 188/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 189/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 190/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 191/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 192/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 193/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 194/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 195/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 196/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 197/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 198/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 199/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 200/240, Train Loss: 0.0000, Val Loss: 0.0005
# Epoch 201/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 202/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 203/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 204/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 205/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 206/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 207/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 208/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 209/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 210/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 211/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 212/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 213/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 214/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 215/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 216/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 217/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 218/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 219/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 220/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 221/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 222/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 223/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 224/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 225/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 226/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 227/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 228/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 229/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 230/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 231/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 232/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 233/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 234/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 235/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 236/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 237/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 238/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 239/240, Train Loss: 0.0000, Val Loss: 0.0004
# Epoch 240/240, Train Loss: 0.0000, Val Loss: 0.0004

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
def evaluate_model(model, test_loader):
    model.eval()
    y_true = []
    y_pred = []

    with torch.no_grad():
        for inputs, targets in test_loader:
            outputs = model(inputs)
            predictions = torch.round(torch.sigmoid(outputs))
            y_true.extend(targets.cpu().numpy())
            y_pred.extend(predictions.cpu().numpy())

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)

    print(f'Accuracy: {accuracy:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'F1 Score: {f1:.4f}')

# %%
evaluate_model(trained_model, test_loader)
# Out:
# Accuracy: 0.9400
# Precision: 0.8889
# Recall: 1.0000
# F1 Score: 0.9412

# %%
# 保存模型
torch.save(trained_model, 'model_complete.pth')

# %%
import torch

# %%
model = torch.load('/content/model_complete.pth')
model.eval()  # 切换到评估模式
# Out:
# VideoClassifier(
#   (pos_embedding): PositionalEmbedding(
#     (position_embeddings): Embedding(120, 1024)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (attention): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=1024, out_features=1024, bias=True)
#     )
#     (dense_proj): Sequential(
#       (0): Linear(in_features=1024, out_features=128, bias=True)
#       (1): GELU(approximate='none')
#       (2): Linear(in_features=128, out_features=1024, bias=True)
#     )
#     (layernorm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (layernorm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (global_pool): AdaptiveAvgPool1d(output_size=1)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=1024, out_features=1, bias=True)
# )

# %%
import torch

# %%
from google.colab import drive
drive.mount('/content/drive')

model_path = '/content/drive/My Drive/model_complete.pth'

# 假设 'model' 是您要保存的 PyTorch 模型
import torch
torch.save(model.state_dict(), model_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import torch.nn as nn

class Basic1DCNN(nn.Module):
    def __init__(self, num_classes=1):
        super(Basic1DCNN, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1024, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        # 假设池化后的序列长度为30，这是一个示例值，根据您的池化层结果进行调整
        self.fc1 = nn.Linear(128 * 30, 512)  # 需要根据实际情况调整
        self.fc2 = nn.Linear(512, num_classes)
        self.relu = nn.ReLU()

    def forward(self, x):
        # Reshape to [batch_size, channels, sequence_length] for Conv1d
        x = x.permute(0, 2, 1)
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = torch.flatten(x, 1)  # Flatten the dimensions except for the batch
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
import torch
from torch.optim import Adam
import torch.nn.functional as F

def distillation_loss(outputs, labels, teacher_outputs, T=20, alpha=0.7):
    """
    Calculate the distillation loss
    :param outputs: Student outputs
    :param labels: True labels
    :param teacher_outputs: Teacher outputs
    :param T: Temperature for softmax
    :param alpha: Weight for the distillation loss
    """
    hard_loss = F.binary_cross_entropy_with_logits(outputs, labels.view(-1, 1))
    soft_loss = F.kl_div(F.log_softmax(outputs/T, dim=1),
                         F.softmax(teacher_outputs/T, dim=1),
                         reduction='batchmean')
    return alpha * soft_loss + (1 - alpha) * hard_loss

# %%
def train_student_with_teacher(teacher_model, student_model, train_loader, optimizer, epochs=10):
    teacher_model.eval()
    for epoch in range(epochs):
        for inputs, targets in train_loader:
            optimizer.zero_grad()


            with torch.no_grad():
                teacher_pred = teacher_model(inputs)


            student_pred = student_model(inputs)


            loss = distillation_loss(student_pred, targets, teacher_pred)


            loss.backward()
            optimizer.step()

        print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# %%
num_epochs = 200

# %%
import torch
from torch.optim import Adam
import torch.nn.functional as F
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

# 假设 Basic1DCNN 类已经被定义
student_model = Basic1DCNN(num_classes=1)
optimizer = Adam(student_model.parameters(), lr=1e-4)

# 假设 train_loader 和 val_loader 已经被定义，可以加载视频数据和标签
num_epochs = 200  # 或根据您的需求调整

def distillation_loss(outputs, labels, teacher_outputs, T=20, alpha=0.7):
    hard_loss = F.binary_cross_entropy_with_logits(outputs, labels)
    soft_loss = F.kl_div(F.log_softmax(outputs/T, dim=1), F.softmax(teacher_outputs/T, dim=1), reduction='batchmean')
    return alpha * soft_loss + (1 - alpha) * hard_loss

for epoch in range(num_epochs):
    student_model.train()
    total_loss = 0
    for inputs, targets in train_loader:
        teacher_outputs = trained_model(inputs)
        student_outputs = student_model(inputs)

        # 确保targets的形状与student_outputs相匹配
        # 如果targets已经是[64, 1]形状，不需要使用unsqueeze(1)
        loss = distillation_loss(student_outputs, targets, teacher_outputs)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / len(train_loader)

    # 验证部分
    student_model.eval()
    val_loss = 0
    true_labels = []
    pred_labels = []
    with torch.no_grad():
        for inputs, targets in val_loader:
            outputs = student_model(inputs)
            loss = F.binary_cross_entropy_with_logits(outputs,targets)
            val_loss += loss.item()

            preds = torch.sigmoid(outputs).round()
            true_labels.extend(targets.numpy())
            pred_labels.extend(preds.numpy())

    avg_val_loss = val_loss / len(val_loader)
    precision = precision_score(true_labels, pred_labels, zero_division=0)
    recall = recall_score(true_labels, pred_labels)
    f1 = f1_score(true_labels, pred_labels)

    print(f'Epoch {epoch+1}/{num_epochs}, Average Train Loss: {avg_loss:.4f}, Average Val Loss: {avg_val_loss:.4f}')
    print(f'Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}')

# %%
import torch
from torch.optim import Adam
import torch.nn.functional as F
from sklearn.metrics import precision_score, recall_score, f1_score, average_precision_score
import numpy as np

# 假设 Basic1DCNN 类已经被定义
student_model = Basic1DCNN(num_classes=1)
optimizer = Adam(student_model.parameters(), lr=1e-4)

# 假设 train_loader 和 val_loader 已经被定义，可以加载视频数据和标签
num_epochs = 200  # 或根据您的需求调整

def distillation_loss(outputs, labels, teacher_outputs, T=20, alpha=0.7):
    hard_loss = F.binary_cross_entropy_with_logits(outputs, labels)  # 确保labels的维度匹配
    soft_loss = F.kl_div(F.log_softmax(outputs/T, dim=1), F.softmax(teacher_outputs/T, dim=1), reduction='batchmean')
    return alpha * soft_loss + (1 - alpha) * hard_loss

for epoch in range(num_epochs):
    student_model.train()
    total_loss = 0
    for inputs, targets in train_loader:
        teacher_outputs = trained_model(inputs)
        student_outputs = student_model(inputs)

        loss = distillation_loss(student_outputs, targets, teacher_outputs)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / len(train_loader)

    # 验证部分
    student_model.eval()
    val_loss = 0
    true_labels = []
    pred_scores = []  # 用于AP计算的预测分数
    with torch.no_grad():
        for inputs, targets in val_loader:
            outputs = student_model(inputs)
            loss = F.binary_cross_entropy_with_logits(outputs, targets)
            val_loss += loss.item()

            pred_scores.extend(torch.sigmoid(outputs).numpy().flatten())  # 收集原始分数
            true_labels.extend(targets.numpy())

    avg_val_loss = val_loss / len(val_loader)
    precision = precision_score(true_labels, np.round(pred_scores), zero_division=0)
    recall = recall_score(true_labels, np.round(pred_scores))
    f1 = f1_score(true_labels, np.round(pred_scores))
    ap = average_precision_score(true_labels, pred_scores)  # 计算AP值

    print(f'Epoch {epoch+1}/{num_epochs}, Average Train Loss: {avg_loss:.4f}, Average Val Loss: {avg_val_loss:.4f}')
    print(f'Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}, AP: {ap:.4f}')
# Out:
# Epoch 1/200, Average Train Loss: 0.2015, Average Val Loss: 0.6208
# Precision: 0.7879, Recall: 0.8667, F1 Score: 0.8254, AP: 0.9443
# Epoch 2/200, Average Train Loss: 0.1857, Average Val Loss: 0.5393
# Precision: 0.7879, Recall: 0.8667, F1 Score: 0.8254, AP: 0.9476
# Epoch 3/200, Average Train Loss: 0.1683, Average Val Loss: 0.4607
# Precision: 0.8125, Recall: 0.8667, F1 Score: 0.8387, AP: 0.9525
# Epoch 4/200, Average Train Loss: 0.1478, Average Val Loss: 0.3891
# Precision: 0.8929, Recall: 0.8333, F1 Score: 0.8621, AP: 0.9606
# Epoch 5/200, Average Train Loss: 0.1180, Average Val Loss: 0.3300
# Precision: 0.8929, Recall: 0.8333, F1 Score: 0.8621, AP: 0.9677
# Epoch 6/200, Average Train Loss: 0.1032, Average Val Loss: 0.2823
# Precision: 0.8710, Recall: 0.9000, F1 Score: 0.8852, AP: 0.9752
# Epoch 7/200, Average Train Loss: 0.0850, Average Val Loss: 0.2507
# Precision: 0.8529, Recall: 0.9667, F1 Score: 0.9062, AP: 0.9838
# Epoch 8/200, Average Train Loss: 0.0638, Average Val Loss: 0.1833
# Precision: 0.9667, Recall: 0.9667, F1 Score: 0.9667, AP: 0.9979
# Epoch 9/200, Average Train Loss: 0.0530, Average Val Loss: 0.1497
# Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AP: 1.0000
# Epoch 10/200, Average Train Loss: 0.0413, Average Val Loss: 0.1193
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 11/200, Average Train Loss: 0.0276, Average Val Loss: 0.1236
# Precision: 1.0000, Recall: 0.9333, F1 Score: 0.9655, AP: 0.9970
# Epoch 12/200, Average Train Loss: 0.0233, Average Val Loss: 0.0870
# Precision: 0.9667, Recall: 0.9667, F1 Score: 0.9667, AP: 0.9989
# Epoch 13/200, Average Train Loss: 0.0202, Average Val Loss: 0.0781
# Precision: 0.9667, Recall: 0.9667, F1 Score: 0.9667, AP: 0.9989
# Epoch 14/200, Average Train Loss: 0.0112, Average Val Loss: 0.1102
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9970
# Epoch 15/200, Average Train Loss: 0.0114, Average Val Loss: 0.0613
# Precision: 0.9667, Recall: 0.9667, F1 Score: 0.9667, AP: 0.9989
# Epoch 16/200, Average Train Loss: 0.0089, Average Val Loss: 0.0569
# Precision: 0.9677, Recall: 1.0000, F1 Score: 0.9836, AP: 0.9989
# Epoch 17/200, Average Train Loss: 0.0060, Average Val Loss: 0.0574
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 18/200, Average Train Loss: 0.0054, Average Val Loss: 0.0532
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 19/200, Average Train Loss: 0.0042, Average Val Loss: 0.0393
# Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AP: 1.0000
# Epoch 20/200, Average Train Loss: 0.0040, Average Val Loss: 0.0410
# Precision: 0.9677, Recall: 1.0000, F1 Score: 0.9836, AP: 1.0000
# Epoch 21/200, Average Train Loss: 0.0041, Average Val Loss: 0.0347
# Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AP: 1.0000
# Epoch 22/200, Average Train Loss: 0.0042, Average Val Loss: 0.0477
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 23/200, Average Train Loss: 0.0035, Average Val Loss: 0.0360
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 24/200, Average Train Loss: 0.0025, Average Val Loss: 0.0367
# Precision: 0.9677, Recall: 1.0000, F1 Score: 0.9836, AP: 1.0000
# Epoch 25/200, Average Train Loss: 0.0018, Average Val Loss: 0.0369
# Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AP: 1.0000
# Epoch 26/200, Average Train Loss: 0.0015, Average Val Loss: 0.0429
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 27/200, Average Train Loss: 0.0016, Average Val Loss: 0.0573
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 28/200, Average Train Loss: 0.0010, Average Val Loss: 0.0532
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 29/200, Average Train Loss: 0.0008, Average Val Loss: 0.0466
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 30/200, Average Train Loss: 0.0007, Average Val Loss: 0.0439
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 31/200, Average Train Loss: 0.0010, Average Val Loss: 0.0453
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 32/200, Average Train Loss: 0.0006, Average Val Loss: 0.0518
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 33/200, Average Train Loss: 0.0006, Average Val Loss: 0.0576
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9979
# Epoch 34/200, Average Train Loss: 0.0008, Average Val Loss: 0.0586
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9979
# Epoch 35/200, Average Train Loss: 0.0005, Average Val Loss: 0.0506
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 36/200, Average Train Loss: 0.0004, Average Val Loss: 0.0453
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 37/200, Average Train Loss: 0.0006, Average Val Loss: 0.0430
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 38/200, Average Train Loss: 0.0004, Average Val Loss: 0.0439
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 39/200, Average Train Loss: 0.0004, Average Val Loss: 0.0469
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 40/200, Average Train Loss: 0.0004, Average Val Loss: 0.0484
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 41/200, Average Train Loss: 0.0003, Average Val Loss: 0.0498
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 42/200, Average Train Loss: 0.0003, Average Val Loss: 0.0506
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 43/200, Average Train Loss: 0.0003, Average Val Loss: 0.0511
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 44/200, Average Train Loss: 0.0004, Average Val Loss: 0.0500
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 45/200, Average Train Loss: 0.0003, Average Val Loss: 0.0462
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 46/200, Average Train Loss: 0.0003, Average Val Loss: 0.0441
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 47/200, Average Train Loss: 0.0002, Average Val Loss: 0.0441
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 48/200, Average Train Loss: 0.0002, Average Val Loss: 0.0448
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 49/200, Average Train Loss: 0.0003, Average Val Loss: 0.0467
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 50/200, Average Train Loss: 0.0003, Average Val Loss: 0.0486
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 51/200, Average Train Loss: 0.0003, Average Val Loss: 0.0507
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 52/200, Average Train Loss: 0.0002, Average Val Loss: 0.0504
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 53/200, Average Train Loss: 0.0002, Average Val Loss: 0.0515
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 54/200, Average Train Loss: 0.0002, Average Val Loss: 0.0532
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 55/200, Average Train Loss: 0.0002, Average Val Loss: 0.0534
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 56/200, Average Train Loss: 0.0002, Average Val Loss: 0.0526
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 57/200, Average Train Loss: 0.0002, Average Val Loss: 0.0523
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 58/200, Average Train Loss: 0.0002, Average Val Loss: 0.0532
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 59/200, Average Train Loss: 0.0002, Average Val Loss: 0.0520
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 60/200, Average Train Loss: 0.0001, Average Val Loss: 0.0520
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 61/200, Average Train Loss: 0.0001, Average Val Loss: 0.0517
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 62/200, Average Train Loss: 0.0001, Average Val Loss: 0.0515
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 63/200, Average Train Loss: 0.0001, Average Val Loss: 0.0511
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 64/200, Average Train Loss: 0.0001, Average Val Loss: 0.0496
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 65/200, Average Train Loss: 0.0001, Average Val Loss: 0.0486
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 66/200, Average Train Loss: 0.0001, Average Val Loss: 0.0488
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 67/200, Average Train Loss: 0.0001, Average Val Loss: 0.0509
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 68/200, Average Train Loss: 0.0001, Average Val Loss: 0.0530
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 69/200, Average Train Loss: 0.0001, Average Val Loss: 0.0542
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 70/200, Average Train Loss: 0.0001, Average Val Loss: 0.0538
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 71/200, Average Train Loss: 0.0001, Average Val Loss: 0.0518
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 72/200, Average Train Loss: 0.0001, Average Val Loss: 0.0502
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 73/200, Average Train Loss: 0.0001, Average Val Loss: 0.0501
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 74/200, Average Train Loss: 0.0001, Average Val Loss: 0.0518
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 75/200, Average Train Loss: 0.0001, Average Val Loss: 0.0557
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 76/200, Average Train Loss: 0.0001, Average Val Loss: 0.0596
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9979
# Epoch 77/200, Average Train Loss: 0.0001, Average Val Loss: 0.0618
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9979
# Epoch 78/200, Average Train Loss: 0.0001, Average Val Loss: 0.0625
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9979
# Epoch 79/200, Average Train Loss: 0.0001, Average Val Loss: 0.0619
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9979
# Epoch 80/200, Average Train Loss: 0.0001, Average Val Loss: 0.0595
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9979
# Epoch 81/200, Average Train Loss: 0.0001, Average Val Loss: 0.0579
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 82/200, Average Train Loss: 0.0001, Average Val Loss: 0.0557
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 83/200, Average Train Loss: 0.0001, Average Val Loss: 0.0552
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 84/200, Average Train Loss: 0.0001, Average Val Loss: 0.0569
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 85/200, Average Train Loss: 0.0001, Average Val Loss: 0.0579
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 86/200, Average Train Loss: 0.0001, Average Val Loss: 0.0579
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 87/200, Average Train Loss: 0.0001, Average Val Loss: 0.0582
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 88/200, Average Train Loss: 0.0001, Average Val Loss: 0.0586
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 89/200, Average Train Loss: 0.0001, Average Val Loss: 0.0592
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 90/200, Average Train Loss: 0.0001, Average Val Loss: 0.0581
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 91/200, Average Train Loss: 0.0001, Average Val Loss: 0.0568
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 92/200, Average Train Loss: 0.0001, Average Val Loss: 0.0574
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 93/200, Average Train Loss: 0.0000, Average Val Loss: 0.0579
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 94/200, Average Train Loss: 0.0001, Average Val Loss: 0.0583
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 95/200, Average Train Loss: 0.0001, Average Val Loss: 0.0574
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 96/200, Average Train Loss: 0.0001, Average Val Loss: 0.0561
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 0.9989
# Epoch 97/200, Average Train Loss: 0.0001, Average Val Loss: 0.0541
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 98/200, Average Train Loss: 0.0000, Average Val Loss: 0.0535
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 99/200, Average Train Loss: 0.0000, Average Val Loss: 0.0542
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 100/200, Average Train Loss: 0.0000, Average Val Loss: 0.0555
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 101/200, Average Train Loss: 0.0001, Average Val Loss: 0.0576
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 102/200, Average Train Loss: 0.0000, Average Val Loss: 0.0598
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 103/200, Average Train Loss: 0.0000, Average Val Loss: 0.0596
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 104/200, Average Train Loss: 0.0001, Average Val Loss: 0.0573
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 105/200, Average Train Loss: 0.0001, Average Val Loss: 0.0551
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 106/200, Average Train Loss: 0.0000, Average Val Loss: 0.0530
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 107/200, Average Train Loss: 0.0000, Average Val Loss: 0.0520
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 108/200, Average Train Loss: 0.0000, Average Val Loss: 0.0521
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 109/200, Average Train Loss: 0.0001, Average Val Loss: 0.0523
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 110/200, Average Train Loss: 0.0000, Average Val Loss: 0.0536
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 111/200, Average Train Loss: 0.0000, Average Val Loss: 0.0556
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 112/200, Average Train Loss: 0.0000, Average Val Loss: 0.0579
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 113/200, Average Train Loss: 0.0000, Average Val Loss: 0.0590
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 114/200, Average Train Loss: 0.0000, Average Val Loss: 0.0580
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 115/200, Average Train Loss: 0.0000, Average Val Loss: 0.0572
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 116/200, Average Train Loss: 0.0000, Average Val Loss: 0.0565
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 117/200, Average Train Loss: 0.0000, Average Val Loss: 0.0561
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 118/200, Average Train Loss: 0.0000, Average Val Loss: 0.0558
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 119/200, Average Train Loss: 0.0000, Average Val Loss: 0.0552
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 120/200, Average Train Loss: 0.0000, Average Val Loss: 0.0563
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 121/200, Average Train Loss: 0.0000, Average Val Loss: 0.0579
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 122/200, Average Train Loss: 0.0000, Average Val Loss: 0.0589
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 123/200, Average Train Loss: 0.0000, Average Val Loss: 0.0600
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 124/200, Average Train Loss: 0.0000, Average Val Loss: 0.0605
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 125/200, Average Train Loss: 0.0000, Average Val Loss: 0.0599
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 126/200, Average Train Loss: 0.0000, Average Val Loss: 0.0581
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 127/200, Average Train Loss: 0.0000, Average Val Loss: 0.0559
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 128/200, Average Train Loss: 0.0000, Average Val Loss: 0.0544
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 129/200, Average Train Loss: 0.0000, Average Val Loss: 0.0546
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 130/200, Average Train Loss: 0.0000, Average Val Loss: 0.0561
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 131/200, Average Train Loss: 0.0000, Average Val Loss: 0.0582
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 132/200, Average Train Loss: 0.0000, Average Val Loss: 0.0599
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 133/200, Average Train Loss: 0.0000, Average Val Loss: 0.0612
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 134/200, Average Train Loss: 0.0000, Average Val Loss: 0.0613
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 135/200, Average Train Loss: 0.0000, Average Val Loss: 0.0605
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 136/200, Average Train Loss: 0.0000, Average Val Loss: 0.0598
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 137/200, Average Train Loss: 0.0000, Average Val Loss: 0.0596
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 138/200, Average Train Loss: 0.0000, Average Val Loss: 0.0591
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 139/200, Average Train Loss: 0.0000, Average Val Loss: 0.0590
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 140/200, Average Train Loss: 0.0000, Average Val Loss: 0.0588
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 141/200, Average Train Loss: 0.0000, Average Val Loss: 0.0588
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 142/200, Average Train Loss: 0.0000, Average Val Loss: 0.0583
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 143/200, Average Train Loss: 0.0000, Average Val Loss: 0.0583
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 144/200, Average Train Loss: 0.0000, Average Val Loss: 0.0581
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 145/200, Average Train Loss: 0.0000, Average Val Loss: 0.0573
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 146/200, Average Train Loss: 0.0000, Average Val Loss: 0.0573
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 147/200, Average Train Loss: 0.0000, Average Val Loss: 0.0570
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 148/200, Average Train Loss: 0.0000, Average Val Loss: 0.0575
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 149/200, Average Train Loss: 0.0000, Average Val Loss: 0.0580
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 150/200, Average Train Loss: 0.0000, Average Val Loss: 0.0584
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 151/200, Average Train Loss: 0.0000, Average Val Loss: 0.0592
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 152/200, Average Train Loss: 0.0000, Average Val Loss: 0.0605
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 153/200, Average Train Loss: 0.0000, Average Val Loss: 0.0623
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 154/200, Average Train Loss: 0.0000, Average Val Loss: 0.0641
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 155/200, Average Train Loss: 0.0000, Average Val Loss: 0.0653
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 156/200, Average Train Loss: 0.0000, Average Val Loss: 0.0658
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 157/200, Average Train Loss: 0.0000, Average Val Loss: 0.0655
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 158/200, Average Train Loss: 0.0000, Average Val Loss: 0.0647
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 159/200, Average Train Loss: 0.0000, Average Val Loss: 0.0625
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 160/200, Average Train Loss: 0.0000, Average Val Loss: 0.0619
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 161/200, Average Train Loss: 0.0000, Average Val Loss: 0.0613
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 162/200, Average Train Loss: 0.0000, Average Val Loss: 0.0610
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 163/200, Average Train Loss: 0.0000, Average Val Loss: 0.0616
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 164/200, Average Train Loss: 0.0000, Average Val Loss: 0.0619
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 165/200, Average Train Loss: 0.0000, Average Val Loss: 0.0620
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 166/200, Average Train Loss: 0.0000, Average Val Loss: 0.0620
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 167/200, Average Train Loss: 0.0000, Average Val Loss: 0.0623
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 168/200, Average Train Loss: 0.0000, Average Val Loss: 0.0621
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 169/200, Average Train Loss: 0.0000, Average Val Loss: 0.0610
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 170/200, Average Train Loss: 0.0000, Average Val Loss: 0.0604
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 171/200, Average Train Loss: 0.0000, Average Val Loss: 0.0606
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 172/200, Average Train Loss: 0.0000, Average Val Loss: 0.0615
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 173/200, Average Train Loss: 0.0000, Average Val Loss: 0.0620
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 174/200, Average Train Loss: 0.0000, Average Val Loss: 0.0618
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 175/200, Average Train Loss: 0.0000, Average Val Loss: 0.0616
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 176/200, Average Train Loss: 0.0000, Average Val Loss: 0.0612
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 177/200, Average Train Loss: 0.0000, Average Val Loss: 0.0603
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 178/200, Average Train Loss: 0.0000, Average Val Loss: 0.0601
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 179/200, Average Train Loss: 0.0000, Average Val Loss: 0.0604
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 180/200, Average Train Loss: 0.0000, Average Val Loss: 0.0608
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 181/200, Average Train Loss: 0.0000, Average Val Loss: 0.0612
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 182/200, Average Train Loss: 0.0000, Average Val Loss: 0.0615
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 183/200, Average Train Loss: 0.0000, Average Val Loss: 0.0612
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 184/200, Average Train Loss: 0.0000, Average Val Loss: 0.0612
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 185/200, Average Train Loss: 0.0000, Average Val Loss: 0.0606
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 186/200, Average Train Loss: 0.0000, Average Val Loss: 0.0591
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 187/200, Average Train Loss: 0.0000, Average Val Loss: 0.0582
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 188/200, Average Train Loss: 0.0000, Average Val Loss: 0.0578
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 189/200, Average Train Loss: 0.0000, Average Val Loss: 0.0581
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 190/200, Average Train Loss: 0.0000, Average Val Loss: 0.0587
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 191/200, Average Train Loss: 0.0000, Average Val Loss: 0.0594
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 192/200, Average Train Loss: 0.0000, Average Val Loss: 0.0604
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 193/200, Average Train Loss: 0.0000, Average Val Loss: 0.0620
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 194/200, Average Train Loss: 0.0000, Average Val Loss: 0.0631
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 195/200, Average Train Loss: 0.0000, Average Val Loss: 0.0634
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 196/200, Average Train Loss: 0.0000, Average Val Loss: 0.0630
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 197/200, Average Train Loss: 0.0000, Average Val Loss: 0.0627
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 198/200, Average Train Loss: 0.0000, Average Val Loss: 0.0621
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 199/200, Average Train Loss: 0.0000, Average Val Loss: 0.0614
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
# Epoch 200/200, Average Train Loss: 0.0000, Average Val Loss: 0.0609
# Precision: 1.0000, Recall: 0.9667, F1 Score: 0.9831, AP: 1.0000
